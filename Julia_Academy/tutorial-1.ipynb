# %% [markdown]
# # Introduction to Julia Course
# [Source](https://juliaacademy.com/courses/375479/lectures/5815852)

# %% [markdown]
# ## Variables

# %%
# types in Julia
an_int = 42
typeof(an_int)
a_float = 3.14159
typeof(a_float)

#=
Variables can be reassigned
It's type will change automatically
=#
a_float = 52
typeof(a_float)
# Out:
# Int64

# %%
# exercise
days = 365
days_float = convert(Float64, days)
# Out:
# 365.0

# %%
@assert days == 365
@assert days_float == 365.0
